# %%
tf_model_path = ’./inception_v1_2016_08_28_frozen.pb’
with open(tf_model_path, ’rb’) as f: serialized = f.read()
# Out:
#   File "<ipython-input-2-f1f594b3f730>", line 1
#     tf_model_path = ’./inception_v1_2016_08_28_frozen.pb’
#                     ^
# SyntaxError: invalid character in identifier

# %%
# .pbファイル読み込み
tf_model_path = './inception_v1_2016_08_28_frozen.pb'

with open(tf_model_path, 'rb') as f:
    serialized = f.read()

# %%
# ファイルからグラフ定義を取得
import tensorflow as tf

tf.reset_default_graph()
gdef = tf.GraphDef()
gdef.ParseFromString(serialized)
# Out:
# 26735789

# %%
with tf.Graph().as_default() as g:

    # ファイルから取得したグラフ定義をインポート 
    tf.import_graph_def(gdef, name='')

    # opのリストを取得
    ops = g.get_operations()

    # 最後から3つのopについて出力名を調べる 
    N = len(ops)
    for i in [N-3,N-2,N-1]:
        print('\nop id {} : op type: "{}"'.format(str(i), ops[i].type));
        for x in ops[i].outputs:
            print("output name = {}".format(x.name)),
# Out:
# op id 1012 : op type: "Softmax"
# output name = InceptionV1/Logits/Predictions/Softmax:0
#
# op id 1013 : op type: "Const"
# output name = InceptionV1/Logits/Predictions/Shape:0
#
# op id 1014 : op type: "Reshape"
# output name = InceptionV1/Logits/Predictions/Reshape_1:0

# %%
import tfcoreml

output_tensor_names = ['InceptionV1/Logits/Predictions/Softmax:0']

coreml_model = tfcoreml.convert(
        tf_model_path=tf_model_path,
        mlmodel_path='./inception_v1_simplest.mlmodel',
        output_feature_names=output_tensor_names)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# ...
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob input:0
# 1/1015: Analysing op name: InceptionV1/Logits/Predictions/Shape ( type:  Const )
# 2/1015: Analysing op name: InceptionV1/Logits/Predictions/Reshape/shape ( type:  Const )
# 3/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases ( type:  Const )
# 4/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases/read ( type:  Identity )
# 5/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights ( type:  Const )
# 6/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights/read ( type:  Identity )
# 7/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/concat_v2/axis ( type:  Const )
# 8/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm/batchnorm/add/y ( type:  Const )
# ...

# %%
class_labels = 'imagenet_slim_labels.txt'
coreml_model = tfcoreml.convert( tf_model_path=tf_model_path,
mlmodel_path='./inception_v1_classlabels.mlmodel', output_feature_names=output_tensor_names, class_labels=class_labels)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# ...
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob input:0
# 1/1015: Analysing op name: InceptionV1/Logits/Predictions/Shape ( type:  Const )
# 2/1015: Analysing op name: InceptionV1/Logits/Predictions/Reshape/shape ( type:  Const )
# 3/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases ( type:  Const )
# 4/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases/read ( type:  Identity )
# 5/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights ( type:  Const )
# 6/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights/read ( type:  Identity )
# 7/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/concat_v2/axis ( type:  Const )
# 8/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm/batchnorm/add/y ( type:  Const )
# ...

# %%
for i in [0,1,2]:
print('\nop id {} : op type: "{}"'.format(str(i), ops[i].type)); for x in ops[i].outputs:
print("output name = {}".format(x.name)),
# Out:
#   File "<ipython-input-14-7cb71590f5b1>", line 2
#     print('\nop id {} : op type: "{}"'.format(str(i), ops[i].type)); for x in ops[i].outputs:
#         ^
# IndentationError: expected an indented block

# %%
# 最初の3つのopについて出力名を調べる
for i in [0,1,2]:
    print('\nop id {} : op type: "{}"'.format(str(i), ops[i].type));
    for x in ops[i].outputs:
        print("output name = {}".format(x.name)),
# Out:
# op id 0 : op type: "Placeholder"
# output name = input:0
#
# op id 1 : op type: "Const"
# output name = InceptionV1/Conv2d_1a_7x7/weights:0
#
# op id 2 : op type: "Identity"
# output name = InceptionV1/Conv2d_1a_7x7/weights/read:0

# %%
image_input_name = ['input:0'] 
coreml_model = tfcoreml.convert( tf_model_path=tf_model_path, mlmodel_path='./inception_v1_imageinput.mlmodel', image_input_names = image_input_name, output_feature_names=output_tensor_names, class_labels=class_labels)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# ...
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob input:0
# 1/1015: Analysing op name: InceptionV1/Logits/Predictions/Shape ( type:  Const )
# 2/1015: Analysing op name: InceptionV1/Logits/Predictions/Reshape/shape ( type:  Const )
# 3/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases ( type:  Const )
# 4/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases/read ( type:  Identity )
# 5/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights ( type:  Const )
# 6/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights/read ( type:  Identity )
# 7/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/concat_v2/axis ( type:  Const )
# 8/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm/batchnorm/add/y ( type:  Const )
# ...

# %%
coreml_model = tfcoreml.convert( tf_model_path=tf_model_path,
mlmodel_path='./inception_v1.mlmodel', output_feature_names=output_tensor_names, image_input_names=image_input_name, class_labels=class_labels,
red_bias = -1, green_bias = -1, blue_bias = -1, image_scale = 2.0/255.0)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# ...
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob input:0
# 1/1015: Analysing op name: InceptionV1/Logits/Predictions/Shape ( type:  Const )
# 2/1015: Analysing op name: InceptionV1/Logits/Predictions/Reshape/shape ( type:  Const )
# 3/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases ( type:  Const )
# 4/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/biases/read ( type:  Identity )
# 5/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights ( type:  Const )
# 6/1015: Analysing op name: InceptionV1/Logits/Conv2d_0c_1x1/weights/read ( type:  Identity )
# 7/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/concat_v2/axis ( type:  Const )
# 8/1015: Analysing op name: InceptionV1/InceptionV1/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm/batchnorm/add/y ( type:  Const )
# ...
